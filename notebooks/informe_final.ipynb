# %% [markdown]
# # **Telecom X - Churn Clientes - Informe Final**

# %% [markdown]
# ###  📖 **Introducción**

# %% [markdown]
# Hemos sido contratados por Telecom X para forma parte del proyecto "Churn de Clientes".
# Nuestra tarea es comprender los factores que llevan a la pérdida de clientes.
# Para ello deberemos recopilar, procesar y analizar datos utilizando python y sus principales bibliotecas.

# %% [markdown]
# ### 🧹 **Limpieza y Tratamiento de Datos**

# %% [markdown]
# La limpieza y tratamiento de datos se realizó en el archivo *etl.ipynb*.
# Para el análisis se utilizó un dataset de 7267 registros de clientes, que incluye variables de clientes, sus servicios, facturación entre otras.
# A continuación se describe brevemente el paso a paso:
#
# 1️⃣ Importación de librerías y datos
#     - Se importaron las librerías necesarias para la manipulación de datos y visualización.
# 2️⃣ Extracción de datos
#     - Se utiliza pd.read_json para cargar el dato desde la url de la api
# 3️⃣ Transformación de datos
#     - Se normaliza los registros que contenían varios niveles anidados
# 4️⃣ Análisis exploratorio de datos inicial
#     - Se validó que no hayan datos faltantes
#     - Se corrigieron los tipo de datos erróneos
#     - Se renombraron las columnas para que sean más descriptivas
#     - Se creó una nueva columna llamada "Cuentas Diarias" que representa la facturación diaria de cada cliente
# 5️⃣ Se guardaron los datos corregidos en *data/df_limpio.csv*
# 6️⃣ Normalización de datos
#     - Para hacer la matriz de correlación se normalizaron los datos, para ello se utilizó la función pd.get_dummies
# 7️⃣ Se guardo el df normalizaro en *data/df_normalizado.csv*

# %% [markdown]
# ### 🔍 **Análisis Exploratorio de Datos**

# %% [markdown]
# El análisis exploratorio de datos se realizó en el archivo *eda.ipynb*.
# A continuación describo brevemente el paso a paso:
#
# 1️⃣ Importación de librerías y datos
#     - Se importaron las librerías necesarias para el análisis exploratorio de datos
#     - Se cargaron los datos desde el archivo *df_limpio.csv*
# 2️⃣ Análisis Descriptivo
#     - Medidas descriptivas de variables numéricas
#     - Medidas descriptivas de variables categóricas
# 3️⃣ Análisis de la variable Churn
#     - Análisis univariado
#     - Análisis bivariado
#     - Análisis multivariado
# 4️⃣ Conteo de evasión según las variables numéricas
# 5️⃣ Correlaciones
#     - Se importaron los datos desde el archivo *df_normalizado.csv*
#     - Matriz de correlación

# %% [markdown]
# **Principales hallazgos visuales y estadísticos**

# %% [markdown]
# **Tasa de Churn**: 26.54% de los clientes abandonaron el servicio.
# **Género**: no se destaca una diferencia entre hombres y mujeres.
# **Edad**: hay una tendencia a que los clientes jóvenes abandonen el servicio.
# **Estado Cívil**: los clientes solteros abandonan más el servicio.
# **Dependientes**: aquellos con personas a su cuidado presentan mayor abandono en el servicio.
# **Respaldo y Soporte Técnico**: aquellos que no cuentan con respaldo y soporte técnico presentan mayor abandono en el servicio.
# **Contrato**: aquellos con contratos mes a mes abandonan más el servicio.
# **Abono**: aquellos que abonan más mensualmente presentan mayor abandono en el servicio.
# **Tiempo de contrato**: en promedio aquellos con contratos de menos de un año abandonan más el servicio.

# %% [markdown]
# **Visualizaciones realizadas**

# %% [markdown]
# **Distribución de Churn**
# **Churn por género**
# **Churn por Adulto Mayor (1=Adulto Mayor)**
# **Churn por estado civil (Yes= tiene pareja)**
# **Churn por Dependientes (Yes=tiene dependientes)**
# **Churn por Múltiples Líneas**
# **Churn por Respaldo Online**
# **Churn por Soporte Técnico**
# **Churn por Tipo de Contrato**
# **Boxplot de Cobro Total por Churn**
# **Boxplot de Cobro Mensual por Churn**
# **Boxplot de Tiempo de Servicio (meses) por Churn**
# **Matriz de correlación**

# %% [markdown]
# ### 🔹**Conclusiones e insights**

# %% [markdown]
# Del análisis realizado se concluye:
# 1- La mayor fuga ocurre en etapas tempranas de contrato.
# 2- Los planes con mayor costo mensual están asociados a mayor churn.
# 3- Los contratos mensuales generan inestabilidad ya que permiten al cliente irse si no está satisfecho.
# 4- Aquellos que no cuentan con respaldo o apoyo técnico generan mayor churn.

# %% [markdown]
# ### 🔹**Recomendaciones estratégicas**

# %% [markdown]
# 1- Implementar un seguimiento proactivo para los clientes durante los primeros meses de suscripción.
# 2- Revisión de costos escalonados para nuevos clientes.
# 3- Incentivar contratos de mayor duración.
# 4- Optimizar la atención al cliente.
# 5- Como siguiente paso se recomienda desarrollar un modelo de predicción de churn para actuar de forma anticipada.
